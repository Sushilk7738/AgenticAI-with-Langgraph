# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content : str

# %%
def create_outline(state: BlogState) -> BlogState:
    #fetch title
    title = state['title']
    
    # call llm generate outline
    prompt = f"Generate a detailed outline for a blog on the topic - {title}"
    outline = model.invoke(prompt).content
    
    # update state
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState)-> BlogState:
    
    title = state['title']
    outline = state['outline']
    
    
    prompt = f"Write a detailed blog on the title - {title} using the following outline \n {outline}"
    
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India '}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India ', 'outline': 'Here\'s a detailed outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and easy to follow.\n\n---\n\n## Blog Title Options:\n\n*   **India\'s AI Ascent: Unpacking the Revolution Shaping a Nation**\n*   **The AI Boom in India: From Silicon Valley to Bharat\'s Digital Frontier**\n*   **Decoding India\'s AI Ambition: Opportunities, Challenges, and the Road Ahead**\n*   **Beyond the Hype: How AI is Reshaping Industries and Lives Across India**\n*   **The Next AI Superpower? Exploring India\'s Rapid Rise in Artificial Intelligence**\n\n---\n\n## Detailed Blog Outline:\n\n### I. Introduction: Setting the Stage for India\'s AI Journey\n\n*   **A. Catchy Hook:**\n    *   Start with a bold statement about AI\'s global impact and its transformative power.\n    *   Mention how AI is no longer a futuristic concept but a present reality shaping industries and daily lives worldwide.\n*   **B. Pivot to India:**\n    *   Introduce India as a rising force in the global technology landscape.\n    *   Briefly highlight India\'s unique position: a massive digital population, a thriving tech ecosystem, and a vast talent pool.\n*   **C. Thesis Statement:**\n    *   State the blog\'s main argument: India is rapidly emerging as a significant player in the global AI arena, driven by innovation, strategic government initiatives, a burgeoning startup ecosystem, and unique societal needs, despite facing certain challenges.\n*   **D. Roadmap:**\n    *   Briefly outline what the blog will cover (e.g., key drivers, sectors impacted, challenges, and future outlook).\n\n### II. The Indian Advantage: Why India is Ripe for AI\n\n*   **A. Digital Transformation & Connectivity:**\n    *   **Jio Effect & Internet Penetration:** Rapid growth in smartphone users and affordable internet.\n    *   **Digital India Initiative:** Government\'s push for digital services and infrastructure.\n    *   **Massive Data Generation:** Abundance of data from a large, digitally active population.\n*   **B. Talent Pool & Research Prowess:**\n    *   **STEM Graduates:** One of the largest pools of science, technology, engineering, and mathematics graduates globally.\n    *   **IT Services Legacy:** Strong foundation in software development and IT outsourcing.\n    *   **Growing Research & Academia:** Increasing focus on AI in universities and research institutions.\n*   **C. Startup Ecosystem & Innovation Hubs:**\n    *   **Vibrant Startup Scene:** India ranks among the top countries for startups.\n    *   **Incubators & Accelerators:** Government and private support for AI-focused ventures.\n    *   **Tier 1 & 2 Cities:** Emergence of AI hubs beyond Bangalore (e.g., Hyderabad, Pune, Chennai, Delhi-NCR).\n*   **D. Cost-Effectiveness & Scalability:**\n    *   Ability to develop and deploy AI solutions at a competitive cost.\n    *   Potential for large-scale adoption due to market size.\n\n### III. AI in Action: Key Sectors & Transformative Applications\n\n*   **A. Healthcare:**\n    *   **Diagnosis & Drug Discovery:** AI-powered tools for faster, more accurate disease detection (e.g., radiology, pathology).\n    *   **Personalized Medicine:** Tailoring treatments based on individual patient data.\n    *   **Telemedicine & Remote Monitoring:** Bridging healthcare gaps in rural areas.\n*   **B. Agriculture:**\n    *   **Crop Yield Optimization:** Predictive analytics for irrigation, pest control, and optimal planting.\n    *   **Weather Forecasting:** Improving accuracy for farmers.\n    *   **Supply Chain Management:** Reducing waste and improving efficiency from farm to market.\n*   **C. Finance & Banking (FinTech):**\n    *   **Fraud Detection:** AI algorithms to identify suspicious transactions.\n    *   **Personalized Banking:** AI-driven recommendations for financial products.\n    *   **Credit Scoring & Risk Assessment:** Enhancing accuracy and inclusion for lending.\n    *   **Robo-Advisors  ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and easy to follow.
#
# ---
#
# ## Blog Title Options:
#
# *   **India's AI Ascent: Unpacking the Revolution Shaping a Nation**
# *   **The AI Boom in India: From Silicon Valley to Bharat's Digital Frontier**
# *   **Decoding India's AI Ambition: Opportunities, Challenges, and the Road Ahead**
# *   **Beyond the Hype: How AI is Reshaping Industries and Lives Across India**
# *   **The Next AI Superpower? Exploring India's Rapid Rise in Artificial Intelligence**
#
# ---
#
# ## Detailed Blog Outline:
#
# ### I. Introduction: Setting the Stage for India's AI Journey
#
# *   **A. Catchy Hook:**
#     *   Start with a bold statement about AI's global impact and its transformative power.
#     *   Mention how AI is no longer a futuristic concept but a present reality shaping industries and daily lives worldwide.
# *   **B. Pivot to India:**
#     *   Introduce India as a rising force in the global technology landscape.
#     *   Briefly highlight India's unique position: a massive digital population, a thriving tech ecosystem, and a vast talent pool.
# *   **C. Thesis Statement:**
#     *   State the blog's main argument: India is rapidly emerging as a significant player in the global AI arena, driven by innovation, strategic government initiatives, a burgeoning startup ecosystem, and unique societal needs, despite facing certain challenges.
# *   **D. Roadmap:**
#     *   Briefly outline what the blog will cover (e.g., key drivers, sectors impacted, challenges, and future outlook).
#
# ### II. The Indian Advantage: Why India is Ripe for AI
#
# *   **A. Digital Transformation & Connectivity:**
#     *   **Jio Effect & Internet Penetration:** Rapid growth in smartphone users and affordable internet.
#     *   **Digital India Initiative:** Government's push for digital services and infrastructure.
#     *   **Massive Data Generation:** Abundance of data from a large, digitally active population.
# *   **B. Talent Pool & Research Prowess:**
#     *   **STEM Graduates:** One of the largest pools of science, technology, engineering, and mathematics graduates globally.
#     *   **IT Services Legacy:** Strong foundation in software development and IT outsourcing.
#     *   **Growing Research & Academia:** Increasing focus on AI in universities and research institutions.
# *   **C. Startup Ecosystem & Innovation Hubs:**
#     *   **Vibrant Startup Scene:** India ranks among the top countries for startups.
#     *   **Incubators & Accelerators:** Government and private support for AI-focused ventures.
#     *   **Tier 1 & 2 Cities:** Emergence of AI hubs beyond Bangalore (e.g., Hyderabad, Pune, Chennai, Delhi-NCR).
# *   **D. Cost-Effectiveness & Scalability:**
#     *   Ability to develop and deploy AI solutions at a competitive cost.
#     *   Potential for large-scale adoption due to market size.
#
# ### III. AI in Action: Key Sectors & Transformative Applications
#
# *   **A. Healthcare:**
#     *   **Diagnosis & Drug Discovery:** AI-powered tools for faster, more accurate disease detection (e.g., radiology, pathology).
#     *   **Personalized Medicine:** Tailoring treatments based on individual patient data.
#     *   **Telemedicine & Remote Monitoring:** Bridging healthcare gaps in rural areas.
# *   **B. Agriculture:**
#     *   **Crop Yield Optimization:** Predictive analytics for irrigation, pest control, and optimal planting.
#     *   **Weather Forecasting:** Improving accuracy for farmers.
#     *   **Supply Chain Management:** Reducing waste and improving efficiency from farm to market.
# *   **C. Finance & Banking (FinTech):**
#     *   **Fraud Detection:** AI algorithms to identify suspicious transactions.
#     *   **Personalized Banking:** AI-driven recommendations for financial products.
#     *   **Credit Scoring & Risk Assessment:** Enhancing accuracy and inclusion for lending.
#     *   **Robo-Advisors & Chatbots:** Improving customer service and investment advice.
# *   **D. Education (EdTech):**
#     *   **Personalized Learning Paths:** AI adapting content to individual student needs.
#     *   **Virtual Tutors & Language Learning:** AI-powered assistance for students.
#     *   **Automated Grading & Feedback:** Streamlining administrative tasks.
# *   **E. E-commerce & Retail:**
#     *   **Personalized Recommendations:** Enhancing customer experience.
#     *   **Supply Chain Optimization:** Inventory management, logistics.
#     *   **Customer Service Chatbots:** 24/7 support.
# *   **F. Public Services & Smart Cities:**
#     *   **Traffic Management:** Optimizing flow and reducing congestion.
#     *   **Waste Management:** Efficient collection and sorting.
#     *   **Citizen Grievance Redressal:** AI-powered platforms for faster resolution.
#     *   **Security & Surveillance:** Enhancing public safety.
#
# ### IV. Driving Forces: Government, Corporate, and Academic Push
#
# *   **A. Government Initiatives & Policy Frameworks:**
#     *   **NITI Aayog's National Strategy for AI:** "AI for All" vision, focusing on inclusive growth.
#     *   **National AI Portal:** A hub for AI-related news, research, and initiatives.
#     *   **Funding & Grants:** Support for AI research and development.
#     *   **Data Policies:** Frameworks for data utilization, sharing, and protection.
# *   **B. Corporate Adoption & Investment:**
#     *   **Large Indian Conglomerates:** Investing heavily in AI R&D and integration (e.g., Reliance, Tata, Mahindra).
#     *   **MNC R&D Centers:** Global tech giants establishing AI research hubs in India.
#     *   **Industry Collaborations:** Partnerships between tech companies and traditional industries.
# *   **C. Academic Research & Skill Development:**
#     *   **Specialized AI Courses:** Universities offering degrees and certifications in AI/ML.
#     *   **Research Labs:** Dedicated AI research centers in IITs, IISc, etc.
#     *   **Online Learning Platforms:** Democratizing AI education and upskilling.
#
# ### V. Challenges and Considerations on the Path to AI Leadership
#
# *   **A. Data Privacy & Security:**
#     *   **Regulatory Gaps:** Evolving data protection laws (e.g., PDP Bill).
#     *   **Cybersecurity Threats:** Protecting sensitive data from breaches.
# *   **B. Ethical AI & Bias:**
#     *   **Algorithmic Bias:** Ensuring fairness and preventing discrimination in AI models.
#     *   **Accountability & Transparency:** Establishing clear guidelines for AI decision-making.
#     *   **Job Displacement & Reskilling:** The potential impact on employment and the need for workforce adaptation.
# *   **C. Infrastructure & Digital Divide:**
#     *   **Compute Power:** Need for robust cloud infrastructure and high-performance computing.
#     *   **Connectivity in Rural Areas:** Ensuring equitable access to digital resources.
#     *   **Data Quality & Availability:** Challenges in collecting and curating high-quality, diverse datasets.
# *   **D. Funding & Investment Gaps:**
#     *   While growing, still a need for more substantial investment in deep-tech AI startups.
#     *   Attracting global venture capital for frontier AI research.
#
# ### VI. The Road Ahead: Future Prospects & Vision for India's AI
#
# *   **A. India as a Global AI Hub:**
#     *   Ambition to be a leader in AI research, development, and deployment.
#     *   Focus on "AI for social good" and solving unique Indian challenges.
# *   **B. Integration with Emerging Technologies:**
#     *   Synergy with IoT, 5G, Blockchain, and Web3 for advanced applications.
#     *   Development of edge AI solutions.
# *   **C. Increased R&D and Intellectual Property:**
#     *   Growing number of AI patents and research publications from India.
#     *   Focus on indigenous AI solutions.
# *   **D. Economic Impact:**
#     *   Projected contribution of AI to India's GDP.
#     *   Creation of new industries and job roles.
#
# ### VII. Conclusion: Embracing a Smarter Future
#
# *   **A. Recap Key Points:**
#     *   Briefly summarize India's unique advantages, the breadth of AI applications, and the driving forces.
#     *   Reiterate the challenges that need careful navigation.
# *   **B. Reiterate Thesis:**
#     *   Emphasize India's undeniable momentum and its pivotal role in shaping the global AI narrative.
# *   **C. Forward-Looking Statement:**
#     *   Conclude with an optimistic yet realistic outlook on India's AI future.
#     *   Stress the importance of responsible innovation, inclusive growth, and ethical considerations.
# *   **D. Call to Action/Thought Provoker (Optional):**
#     *   "What role do you see AI playing in India's journey towards becoming a developed nation?"
#     *   "How can we ensure that the benefits of AI are accessible to all Indians?"
#
# ---

# %%
print(final_state["content"])
# Out:
# # India's AI Ascent: Unpacking the Revolution Shaping a Nation
#
# In an era where technology constantly redefines the boundaries of possibility, Artificial Intelligence (AI) stands as a monumental force, no longer a futuristic concept but a present reality shaping industries and daily lives worldwide. From powering personalized recommendations to revolutionizing scientific discovery, AI's transformative power is undeniable, and its global impact is growing exponentially.
#
# Amidst this global technological wave, one nation is rapidly emerging as a pivotal player: India. With its massive digital population, a thriving tech ecosystem, and an unparalleled talent pool, India is uniquely positioned at the forefront of the AI revolution. This isn't just about adopting technology; it's about harnessing AI to solve unique societal challenges, drive economic growth, and leapfrog development. India is rapidly emerging as a significant player in the global AI arena, driven by innovation, strategic government initiatives, a burgeoning startup ecosystem, and unique societal needs, despite facing certain challenges.
#
# This blog will delve into the multifaceted rise of AI in India, exploring the key drivers behind its ascent, the sectors it's profoundly impacting, the forces propelling its growth, the challenges that need careful navigation, and the ambitious vision for its future.
#
# ---
#
# ## The Indian Advantage: Why India is Ripe for AI
#
# India's journey into the AI future isn't a mere coincidence; it's a culmination of several powerful factors that make it a fertile ground for AI innovation and adoption.
#
# ### Digital Transformation & Connectivity
# The "Jio Effect" has been nothing short of revolutionary, dramatically increasing smartphone penetration and making affordable internet accessible to hundreds of millions. This has been bolstered by the government's ambitious "Digital India Initiative," pushing for digital services and infrastructure across the nation. The result? A massive, digitally active population generating an unprecedented abundance of data – the lifeblood of AI.
#
# ### Talent Pool & Research Prowess
# India boasts one of the largest pools of Science, Technology, Engineering, and Mathematics (STEM) graduates globally. Building on its robust IT services legacy, which has honed its software development and outsourcing capabilities for decades, India now sees a growing focus on AI in its universities and research institutions. This strong foundation provides the intellectual capital necessary for groundbreaking AI development.
#
# ### Startup Ecosystem & Innovation Hubs
# India proudly ranks among the top countries for startups, fostering a vibrant scene that's increasingly gravitating towards AI. Government and private incubators and accelerators are actively supporting AI-focused ventures. While Bangalore remains a tech powerhouse, AI hubs are rapidly emerging in Tier 1 and 2 cities like Hyderabad, Pune, Chennai, and Delhi-NCR, decentralizing innovation.
#
# ### Cost-Effectiveness & Scalability
# A significant advantage for India is its ability to develop and deploy AI solutions at a highly competitive cost. Coupled with the sheer size of its market, this translates into immense potential for large-scale adoption, making AI accessible and impactful for a vast population.
#
# ---
#
# ## AI in Action: Key Sectors & Transformative Applications
#
# AI isn't just an abstract concept in India; it's actively transforming critical sectors, offering solutions to long-standing problems and creating new opportunities.
#
# ### Healthcare
# AI is a game-changer in Indian healthcare, addressing issues of access and accuracy. AI-powered tools are enabling faster, more accurate disease detection in radiology and pathology, aiding in early diagnosis. Personalized medicine, tailoring treatments based on individual patient data, is becoming a reality. Crucially, telemedicine and remote monitoring, often powered by AI, are bridging healthcare gaps in rural areas, bringing specialist care to remote villages.
#
# ### Agriculture
# For a nation where agriculture is the backbone, AI offers a new lease on life. Predictive analytics help farmers optimize crop yields by advising on irrigation, pest control, and optimal planting times. AI improves weather forecasting accuracy, empowering farmers to make informed decisions. Furthermore, AI-driven supply chain management reduces waste and improves efficiency from farm to market, ensuring better returns for farmers.
#
# ### Finance & Banking (FinTech)
# The FinTech sector is embracing AI with open arms. AI algorithms are crucial for sophisticated fraud detection, identifying suspicious transactions in real-time. Personalized banking experiences, with AI-driven recommendations for financial products, are enhancing customer satisfaction. AI is also revolutionizing credit scoring and risk assessment, enhancing accuracy and promoting financial inclusion for lending. Robo-advisors and chatbots are improving customer service and democratizing investment advice.
#
# ### Education (EdTech)
# AI is personalizing learning on an unprecedented scale. AI adapts content to individual student needs, creating personalized learning paths. Virtual tutors and AI-powered language learning tools provide accessible assistance. Automated grading and feedback systems streamline administrative tasks, allowing educators to focus more on teaching.
#
# ### E-commerce & Retail
# In India's booming e-commerce sector, AI is central to enhancing customer experience through personalized recommendations. It optimizes supply chain management, improving inventory management and logistics. AI-powered customer service chatbots provide 24/7 support, ensuring seamless interactions.
#
# ### Public Services & Smart Cities
# AI is instrumental in the vision of Smart Cities. It optimizes traffic management, reducing congestion and improving urban mobility. AI-driven solutions are enhancing waste management through efficient collection and sorting. Citizen grievance redressal platforms powered by AI ensure faster resolution of public issues, while enhanced security and surveillance systems improve public safety.
#
# ---
#
# ## Driving Forces: Government, Corporate, and Academic Push
#
# The rapid integration of AI in India is not organic alone; it's a concerted effort from multiple stakeholders.
#
# ### Government Initiatives & Policy Frameworks
# The Indian government has recognized AI's potential and is actively shaping its future. NITI Aayog's "National Strategy for AI" with its "AI for All" vision, focuses on inclusive growth and leveraging AI for social good. The National AI Portal serves as a comprehensive hub for AI-related news, research, and initiatives. Significant funding and grants are being allocated for AI research and development, alongside the formulation of data policies that provide frameworks for data utilization, sharing, and protection.
#
# ### Corporate Adoption & Investment
# Large Indian conglomerates like Reliance, Tata, and Mahindra are investing heavily in AI R&D and integrating AI across their diverse business verticals. Global tech giants have established substantial AI research and development centers in India, leveraging the talent pool. Furthermore, industry collaborations between tech companies and traditional industries are accelerating AI adoption across various sectors.
#
# ### Academic Research & Skill Development
# Indian universities are stepping up, offering specialized AI courses, degrees, and certifications in AI/ML to meet the growing demand for skilled professionals. Premier institutions like the IITs and IISc have established dedicated AI research labs, pushing the boundaries of innovation. Online learning platforms are playing a crucial role in democratizing AI education and upskilling the workforce, making learning accessible to a broader audience.
#
# ---
#
# ## Challenges and Considerations on the Path to AI Leadership
#
# Despite its impressive momentum, India's AI journey is not without its hurdles, demanding careful navigation and strategic foresight.
#
# ### Data Privacy & Security
# As India generates vast amounts of data, regulatory gaps in data protection laws (like the evolving Personal Data Protection Bill) pose significant challenges. Ensuring robust cybersecurity measures to protect sensitive data from breaches is paramount to maintaining public trust and national security.
#
# ### Ethical AI & Bias
# The potential for algorithmic bias, leading to unfairness or discrimination in AI models, is a serious concern, especially in a diverse country like India. Establishing clear guidelines for accountability and transparency in AI decision-making is crucial. Moreover, the potential for job displacement due to automation necessitates proactive measures for reskilling and upskilling the workforce to adapt to new roles.
#
# ### Infrastructure & Digital Divide
# Developing and deploying advanced AI requires robust cloud infrastructure and high-performance computing capabilities, which need continuous investment. While internet penetration has grown, ensuring equitable connectivity in rural areas remains a challenge, risking a widening digital divide. Furthermore, challenges persist in collecting and curating high-quality, diverse, and representative datasets, which are essential for training effective and unbiased AI models.
#
# ### Funding & Investment Gaps
# While investment in AI startups is growing, there is still a need for more substantial funding, particularly for deep-tech AI ventures that require long-term capital. Attracting global venture capital for frontier AI research and development is crucial to compete on the international stage.
#
# ---
#
# ## The Road Ahead: Future Prospects & Vision for India's AI
#
# India's AI ambition is clear: to be a global leader, not just a follower.
#
# ### India as a Global AI Hub
# The vision is for India to emerge as a preeminent hub for AI research, development, and deployment, with a strong focus on "AI for social good" – leveraging AI to solve unique Indian challenges related to health, agriculture, and education.
#
# ### Integration with Emerging Technologies
# The future of AI in India lies in its synergy with other emerging technologies like IoT, 5G, Blockchain, and Web3, enabling advanced and interconnected applications. There's also a growing emphasis on the development of edge AI solutions, bringing AI processing closer to the data source for faster, more efficient operations.
#
# ### Increased R&D and Intellectual Property
# India is poised to see a significant increase in AI patents and research publications, reflecting a growing focus on indigenous AI solutions tailored to its unique context and needs.
#
# ### Economic Impact
# AI is projected to contribute substantially to India's GDP, driving economic growth, fostering innovation, and creating a plethora of new industries and job roles across various sectors.
#
# ---
#
# ## Conclusion: Embracing a Smarter Future
#
# India's journey in Artificial Intelligence is a dynamic narrative of immense potential, rapid innovation, and strategic vision. Its unique advantages – a vast digital population, a rich talent pool, and a vibrant startup ecosystem – have positioned it as a formidable force on the global AI stage. We've seen how AI is already transforming critical sectors from healthcare to agriculture, driven by a powerful synergy between government initiatives, corporate investments, and academic excellence.
#
# While challenges related to data privacy, ethical considerations, infrastructure, and funding persist, India's commitment to responsible innovation and inclusive growth remains unwavering. The nation is not merely adopting AI; it is actively shaping its future, aiming to leverage this transformative technology for social good and economic prosperity.
#
# India's undeniable momentum and its pivotal role in shaping the global AI narrative mark it as a nation embracing a smarter, more efficient, and more inclusive future. The question is no longer *if* AI will transform India, but *how deeply* and *how broadly* its benefits will be woven into the fabric of the nation.
#
# **What role do you see AI playing in India's journey towards becoming a developed nation? How can we ensure that the benefits of AI are accessible to all Indians? Share your thoughts below!**
